# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#     epoch      loss       acc
# 0       1  3.186267  0.172255
# 1       2  2.254498  0.363731
# 2       3  1.838585  0.463883
# 3       4  1.673409  0.510928
# 4       5  1.564884  0.535513
# ..    ...       ...       ...
# 95     96  0.246409  0.916659
# 96     97  0.239755  0.918217
# 97     98  0.239318  0.918814
# 98     99  0.235716  0.920023
# 99    100  0.234605  0.920263
#
# [100 rows x 3 columns]

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.show()
